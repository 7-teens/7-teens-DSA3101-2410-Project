# %%
# Processing libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # Importing Data

# %%
orders = pd.read_csv("../Cleaned_Datasets/orders_generated.csv", index_col=0) #order data file
customer = pd.read_csv("../Cleaned_Datasets/customer_SG_only.csv", index_col=0) #main user data file
products = pd.read_csv("../Cleaned_Datasets/products_cleaned.csv", index_col=0)

# %%
products
# Out:
#          price_ori                               item_category_detail  \
# 0         8.034430  Shopee | Women's Bags | Shoulder Bags | Should...
# 1         0.439091  Shopee | Home Appliances | Sewing Machines | S...
# 2         2.647002    Shopee | Women's Bags | Handbags | Set Handbags
# 3         2.709284  Shopee | Women Clothes | Maternity Wear | Inne...
# 4      1245.336605   Shopee | Cameras & Drones | DSLR Cameras | DSLRs
# ...            ...                                                ...
# 20307    15.757447  Shopee | Baby & Toys | Girls Fashion | Girl Shoes
# 20308     9.965184  Shopee | Baby & Toys | Girls Fashion | Girl Dr...
# 20309     1.550832  Shopee | Muslim Fashion | Kain Pasang & Songke...
# 20310     0.093424             Shopee | Baby & Toys | Others | Others
# 20311     7.785300  Shopee | Fashion Accessories | Eyewear | Eyegl...
#
#                                                    title item_rating  \
# 0      1081 PU SLING BAG KULIT leather Casual Beg Tan...         4.9
# 1      Stat Chinese Traditional Frog Buttons Knot Che...         5.0
# 2      N09 READY STOCK MYFOOYIN woman handbag set 2in...         4.9
# 3      🔥Shocking Sale🔥Cotton Comfort Nursing Bra Brea...         4.9
# 4      Canon EOS 70D 18-55mm IS STM Original+64gb+ext...         5.0
# ...                                                  ...         ...
# 20307  Elegant All-match Girls Leather Flat Shoes Pea...         4.9
# 20308          Baju Raya kids 2023(v1) | Shopee Malaysia         4.8
# 20309  Kain como crepe heavy premium (harga untk 0.5m...         4.7
# 20310  Doorgift Bag Birthday Kids Drawstring Organize...         4.9
# 20311  Chris kacamata hitam anti silau | Shopee Malaysia         4.6
#
#                seller_name  price_actual  total_rating  total_sold  favorite  \
# 0             qqfwholesale      4.017215         179.0       179.0     128.0
# 1            stationery.my      0.233559          17.0        17.0      19.0
# 2                 fooyin88      2.647002        8100.0      8100.0   21500.0
# 3                 vivi2002      2.709284        6500.0      6500.0    3400.0
# 4              xpro.gadget    852.957480          10.0        10.0     132.0
# ...                    ...           ...           ...         ...       ...
# 20307             amour.my      9.454468         219.0       219.0    1600.0
# 20308                mazu9      9.965184         215.0       215.0     304.0
# 20309  nurlainafashionzone      0.775416         152.0       152.0      98.0
# 20310           pbs_empire      0.093424          16.0        16.0      27.0
# 20311           ilham02_02      7.785300          89.0        89.0      61.0
#
#                                                     desc   Stock Ships_From  \
# 0      🎉 WELCOME To QQF WHOLESALE \r\n😍 ALL item read...    2906   Malaysia
# 1      Chinese Traditional Frog Buttons Knot Cheongsa...   31701      China
# 2      READY STOCK\nMEASUREMENT:\nLONG 26CM X HEIGHT ...    2044   Malaysia
# 3      PRODUCT DESCRIPTION\nMaterial:95%Cotton+5%Span...     386   Malaysia
# 4      Canon 70D\nHighlights\nEF-S 18-55mm f/3.5-5.6 ...      36   Malaysia
# ...                                                  ...     ...        ...
# 20307  1 cm = 0.3937 inch \r\n-----------------------...   19076      China
# 20308   M G FASHION\n-stylist fashionable\n-comfortab...    9406   Malaysia
# 20309   Harga utk 0.5m@setengah meter / HARGA BUKAN U...  446287   Malaysia
# 20310  Custom made Ready Stock in Malaysia\nUnicorn S...    3695   Malaysia
# 20311  @normal set bermaksud anda dapat set cermin ma...    6800   Malaysia
#
#        product_id        main_category           mid_category  \
# 0               1         Women's Bags          Shoulder Bags
# 1               2      Home Appliances        Sewing Machines
# 2               3         Women's Bags               Handbags
# 3               4        Women Clothes         Maternity Wear
# 4               5     Cameras & Drones           DSLR Cameras
# ...           ...                  ...                    ...
# 20307       20308          Baby & Toys          Girls Fashion
# 20308       20309          Baby & Toys          Girls Fashion
# 20309       20310       Muslim Fashion  Kain Pasang & Songket
# 20310       20311          Baby & Toys                 Others
# 20311       20312  Fashion Accessories                Eyewear
#
#                           sub_category
# 0                        Shoulder Bags
# 1      Sewing Machines and Accessories
# 2                         Set Handbags
# 3                            Innerwear
# 4                                DSLRs
# ...                                ...
# 20307                       Girl Shoes
# 20308                     Girl Dresses
# 20309               Kain Pasang Cotton
# 20310                           Others
# 20311                       Eyeglasses
#
# [20312 rows x 16 columns]

# %%
orders
# Out:
#           order_id                  order_time  product_id  customer_id
# 0          order_1  2019-11-11 13:50:53.819019       17393          299
# 1          order_2  2019-11-27 05:41:28.793190        7725          299
# 2          order_3  2019-10-19 10:00:48.691390       10948          299
# 3          order_4  2019-10-09 18:24:32.264380       19083          299
# 4          order_5  2019-10-29 04:41:47.170388        7954          299
# ...            ...                         ...         ...          ...
# 65888  order_65889  2019-03-18 20:34:28.868262       10328       127744
# 65889  order_65890  2019-03-15 09:41:12.357500        1794       127744
# 65890  order_65891  2019-05-05 03:52:57.607549        8767       127744
# 65891  order_65892  2019-08-16 06:17:57.704049       11112       127744
# 65892  order_65893  2019-03-25 15:29:08.967064        4471       127744
#
# [65893 rows x 4 columns]

# %%
# Map product_id back to its price
product_id_to_price = products.set_index('product_id')['price_actual'].to_dict()

orders['price'] = orders['product_id'].map(product_id_to_price)

# Create the delivery dataframe
delivery = orders.copy()
# delivery['product_id'] = weighted_product_ids

# Map product_id back to its category
product_id_to_category = products.set_index('product_id')['main_category'].to_dict()

# Add category column to the delivery dataframe
delivery['main_category'] = delivery['product_id'].map(product_id_to_category)

# Display the distribution of the categories in the delivery dataframe
print(delivery['main_category'].value_counts(normalize=True)*100)
# Out:
# main_category
# Health & Beauty           11.881383
# Men Clothes               11.861655
# Women Clothes             11.092225
# Mobile & Accessories       9.146647
# Baby & Toys                7.463615
# Home & Living              6.584918
# Groceries & Pets           5.492237
# Home Appliances            4.627199
# Automotive                 4.225031
# Sports & Outdoor           3.780371
# Women's Bags               3.158150
# Watches                    2.672515
# Men's Bags & Wallets       2.362922
# Cameras & Drones           2.309805
# Women Shoes                2.171703
# Muslim Fashion             2.110998
# Fashion Accessories        2.038153
# Computer & Accessories     1.912191
# Games, Books & Hobbies     1.746771
# Men Shoes                  1.025906
# Gaming & Consoles          0.763359
# Travel & Luggage           0.760324
# Tickets & Vouchers         0.537235
# Others                     0.274688
# Name: proportion, dtype: float64

# %%
# Generate delivery times
is_on_time = np.random.rand(len(orders)) < 0.8  # 80% on-time deliveries
delivery_times = np.where(is_on_time, 
                          np.random.normal(loc=1.34, scale=0.3, size=len(orders)),  # On-time deliveries
                          np.random.uniform(2, 5, size=len(orders)))  # Late deliveries between 2 to 5 days

delivery_times = np.maximum(1, delivery_times).round(1)  # Ensure no delivery times below 1 day

# Add delivery times and calculate delivered_date
delivery['delivery_time'] = delivery_times
delivery['delivered_date'] = pd.to_datetime(orders['order_time']) + pd.to_timedelta(delivery['delivery_time'], unit='D')

# Define the delivery costs based on the main_category column
def assign_delivery_cost(row):
    category = row['main_category']  # Use main_category instead of generating a new category
    
    # Define the courier costs based on the options you gave
    if category in ['Men Clothes', 'Women Clothes']:
        return 3.20  # SmartPac delivery for clothes
    elif category == 'Health & Beauty':
        return 3.30  # Ninja Packs (XS) for Health & Beauty
    elif category == 'Mobile & Accessories':
        return 3.98  # Ninja Packs (M) for Mobile & Accessories
    elif category == 'Home & Living':
        return 4.30  # Qxpress Delivery 5kg for Home items
    elif category == 'Automotive':
        return 6.90  # Qxpress Delivery 10kg for Automotive
    elif category == 'Sports & Outdoor':
        return 4.48  # Ninja Packs (Padded M) for Sports & Outdoor
    elif category == 'Groceries & Pets':
        return 3.20  # SmartPac for Groceries & Pets
    elif category == 'Home Appliances':
        return 5.30  # Qxpress Delivery 10kg for Home Appliances
    elif category in ['Women\'s Bags', 'Men\'s Bags & Wallets']:
        return 3.20  # SmartPac for Bags
    elif category in ['Watches', 'Cameras & Drones']:
        return 7.30  # GrabExpress for Watches and Cameras
    else:
        return 3.98  # Default delivery cost

# Apply the delivery cost assignment function to each row based on category_1
delivery['delivery_cost'] = delivery.apply(assign_delivery_cost, axis=1)

delivery
# Out:
#           order_id                  order_time  product_id  customer_id  \
# 0          order_1  2019-11-11 13:50:53.819019       17393          299
# 1          order_2  2019-11-27 05:41:28.793190        7725          299
# 2          order_3  2019-10-19 10:00:48.691390       10948          299
# 3          order_4  2019-10-09 18:24:32.264380       19083          299
# 4          order_5  2019-10-29 04:41:47.170388        7954          299
# ...            ...                         ...         ...          ...
# 65888  order_65889  2019-03-18 20:34:28.868262       10328       127744
# 65889  order_65890  2019-03-15 09:41:12.357500        1794       127744
# 65890  order_65891  2019-05-05 03:52:57.607549        8767       127744
# 65891  order_65892  2019-08-16 06:17:57.704049       11112       127744
# 65892  order_65893  2019-03-25 15:29:08.967064        4471       127744
#
#             price         main_category  delivery_time  \
# 0      871.642200  Mobile & Accessories            1.8
# 1        0.772302       Home Appliances            1.7
# 2       21.923405           Baby & Toys            1.0
# 3        0.174391           Baby & Toys            3.8
# 4        0.619710           Men Clothes            1.3
# ...           ...                   ...            ...
# 65888    9.030948           Baby & Toys            1.6
# 65889    7.785300         Women Clothes            1.4
# 65890   30.829788           Baby & Toys            2.1
# 65891   77.541589         Women Clothes            1.3
# 65892    0.467118           Men Clothes            1.0
#
#                   delivered_date  delivery_cost
# 0     2019-11-13 09:02:53.819019           3.98
# 1     2019-11-28 22:29:28.793190           5.30
# 2     2019-10-20 10:00:48.691390           3.98
# 3     2019-10-13 13:36:32.264380           3.98
# 4     2019-10-30 11:53:47.170388           3.20
# ...                          ...            ...
# 65888 2019-03-20 10:58:28.868262           3.98
# 65889 2019-03-16 19:17:12.357500           3.20
# 65890 2019-05-07 06:16:57.607549           3.98
# 65891 2019-08-17 13:29:57.704049           3.20
# 65892 2019-03-26 15:29:08.967064           3.20
#
# [65893 rows x 9 columns]

# %%
delivery.product_id.value_counts()
delivery[delivery.product_id == 4362]
# Out:
#           order_id                  order_time  product_id  customer_id  \
# 1359    order_1360  2019-12-26 06:09:16.560519        4362        51119
# 17506  order_17507  2019-02-28 09:11:56.881426        4362        88942
# 20605  order_20606  2019-04-24 14:46:20.226082        4362        62494
# 22219  order_22220  2019-01-23 01:22:31.728422        4362        73783
# 25873  order_25874  2019-06-07 08:45:01.657101        4362        24206
# 36565  order_36566  2019-04-16 12:09:40.748286        4362       117080
# 37276  order_37277  2019-02-15 23:22:08.854609        4362        60275
# 42766  order_42767  2019-09-13 06:00:19.738737        4362        75902
# 50326  order_50327  2019-08-21 17:18:45.691220        4362        97229
# 51512  order_51513  2019-07-25 21:29:13.111043        4362        97229
# 58953  order_58954  2019-04-06 19:35:19.414637        4362        34337
# 62535  order_62536  2019-08-08 02:12:28.877572        4362        73618
# 63973  order_63974  2019-03-17 17:30:51.752631        4362       104428
#
#            price main_category  delivery_time             delivered_date  \
# 1359   94.669249   Baby & Toys            1.7 2019-12-27 22:57:16.560519
# 17506  94.669249   Baby & Toys            1.1 2019-03-01 11:35:56.881426
# 20605  94.669249   Baby & Toys            1.4 2019-04-26 00:22:20.226082
# 22219  94.669249   Baby & Toys            2.4 2019-01-25 10:58:31.728422
# 25873  94.669249   Baby & Toys            3.0 2019-06-10 08:45:01.657101
# 36565  94.669249   Baby & Toys            1.4 2019-04-17 21:45:40.748286
# 37276  94.669249   Baby & Toys            1.6 2019-02-17 13:46:08.854609
# 42766  94.669249   Baby & Toys            1.3 2019-09-14 13:12:19.738737
# 50326  94.669249   Baby & Toys            1.4 2019-08-23 02:54:45.691220
# 51512  94.669249   Baby & Toys            1.8 2019-07-27 16:41:13.111043
# 58953  94.669249   Baby & Toys            1.1 2019-04-07 21:59:19.414637
# 62535  94.669249   Baby & Toys            1.4 2019-08-09 11:48:28.877572
# 63973  94.669249   Baby & Toys            1.5 2019-03-19 05:30:51.752631
#
#        delivery_cost
# 1359            3.98
# 17506           3.98
# 20605           3.98
# 22219           3.98
# 25873           3.98
# 36565           3.98
# 37276           3.98
# 42766           3.98
# 50326           3.98
# 51512           3.98
# 58953           3.98
# 62535           3.98
# 63973           3.98

# %%
(delivery.delivery_time > 2).value_counts(normalize=True)*100
# Out:
# delivery_time
# False    79.818797
# True     20.181203
# Name: proportion, dtype: float64

# %%
delivery.main_category.value_counts(normalize=True)*100
# Out:
# main_category
# Health & Beauty           11.881383
# Men Clothes               11.861655
# Women Clothes             11.092225
# Mobile & Accessories       9.146647
# Baby & Toys                7.463615
# Home & Living              6.584918
# Groceries & Pets           5.492237
# Home Appliances            4.627199
# Automotive                 4.225031
# Sports & Outdoor           3.780371
# Women's Bags               3.158150
# Watches                    2.672515
# Men's Bags & Wallets       2.362922
# Cameras & Drones           2.309805
# Women Shoes                2.171703
# Muslim Fashion             2.110998
# Fashion Accessories        2.038153
# Computer & Accessories     1.912191
# Games, Books & Hobbies     1.746771
# Men Shoes                  1.025906
# Gaming & Consoles          0.763359
# Travel & Luggage           0.760324
# Tickets & Vouchers         0.537235
# Others                     0.274688
# Name: proportion, dtype: float64

# %%
delivery['delivery_id'] = np.arange(1, len(delivery) + 1)
delivery
# Out:
#           order_id                  order_time  product_id  customer_id  \
# 0          order_1  2019-11-11 13:50:53.819019       17393          299
# 1          order_2  2019-11-27 05:41:28.793190        7725          299
# 2          order_3  2019-10-19 10:00:48.691390       10948          299
# 3          order_4  2019-10-09 18:24:32.264380       19083          299
# 4          order_5  2019-10-29 04:41:47.170388        7954          299
# ...            ...                         ...         ...          ...
# 65888  order_65889  2019-03-18 20:34:28.868262       10328       127744
# 65889  order_65890  2019-03-15 09:41:12.357500        1794       127744
# 65890  order_65891  2019-05-05 03:52:57.607549        8767       127744
# 65891  order_65892  2019-08-16 06:17:57.704049       11112       127744
# 65892  order_65893  2019-03-25 15:29:08.967064        4471       127744
#
#             price         main_category  delivery_time  \
# 0      871.642200  Mobile & Accessories            1.8
# 1        0.772302       Home Appliances            1.7
# 2       21.923405           Baby & Toys            1.0
# 3        0.174391           Baby & Toys            3.8
# 4        0.619710           Men Clothes            1.3
# ...           ...                   ...            ...
# 65888    9.030948           Baby & Toys            1.6
# 65889    7.785300         Women Clothes            1.4
# 65890   30.829788           Baby & Toys            2.1
# 65891   77.541589         Women Clothes            1.3
# 65892    0.467118           Men Clothes            1.0
#
#                   delivered_date  delivery_cost  delivery_id
# 0     2019-11-13 09:02:53.819019           3.98            1
# 1     2019-11-28 22:29:28.793190           5.30            2
# 2     2019-10-20 10:00:48.691390           3.98            3
# 3     2019-10-13 13:36:32.264380           3.98            4
# 4     2019-10-30 11:53:47.170388           3.20            5
# ...                          ...            ...          ...
# 65888 2019-03-20 10:58:28.868262           3.98        65889
# 65889 2019-03-16 19:17:12.357500           3.20        65890
# 65890 2019-05-07 06:16:57.607549           3.98        65891
# 65891 2019-08-17 13:29:57.704049           3.20        65892
# 65892 2019-03-26 15:29:08.967064           3.20        65893
#
# [65893 rows x 10 columns]

# %%
# Create a mapping from seller_name to unique shop_id
seller_name_to_shop_id = {name: idx for idx, name in enumerate(products['seller_name'].unique(), start=1)}

# Assign shop_id to the products dataframe
products['seller_id'] = products['seller_name'].map(seller_name_to_shop_id)

# Display the first few rows of the updated products dataframe
products
# Out:
#          price_ori                               item_category_detail  \
# 0         8.034430  Shopee | Women's Bags | Shoulder Bags | Should...
# 1         0.439091  Shopee | Home Appliances | Sewing Machines | S...
# 2         2.647002    Shopee | Women's Bags | Handbags | Set Handbags
# 3         2.709284  Shopee | Women Clothes | Maternity Wear | Inne...
# 4      1245.336605   Shopee | Cameras & Drones | DSLR Cameras | DSLRs
# ...            ...                                                ...
# 20307    15.757447  Shopee | Baby & Toys | Girls Fashion | Girl Shoes
# 20308     9.965184  Shopee | Baby & Toys | Girls Fashion | Girl Dr...
# 20309     1.550832  Shopee | Muslim Fashion | Kain Pasang & Songke...
# 20310     0.093424             Shopee | Baby & Toys | Others | Others
# 20311     7.785300  Shopee | Fashion Accessories | Eyewear | Eyegl...
#
#                                                    title item_rating  \
# 0      1081 PU SLING BAG KULIT leather Casual Beg Tan...         4.9
# 1      Stat Chinese Traditional Frog Buttons Knot Che...         5.0
# 2      N09 READY STOCK MYFOOYIN woman handbag set 2in...         4.9
# 3      🔥Shocking Sale🔥Cotton Comfort Nursing Bra Brea...         4.9
# 4      Canon EOS 70D 18-55mm IS STM Original+64gb+ext...         5.0
# ...                                                  ...         ...
# 20307  Elegant All-match Girls Leather Flat Shoes Pea...         4.9
# 20308          Baju Raya kids 2023(v1) | Shopee Malaysia         4.8
# 20309  Kain como crepe heavy premium (harga untk 0.5m...         4.7
# 20310  Doorgift Bag Birthday Kids Drawstring Organize...         4.9
# 20311  Chris kacamata hitam anti silau | Shopee Malaysia         4.6
#
#                seller_name  price_actual  total_rating  total_sold  favorite  \
# 0             qqfwholesale      4.017215         179.0       179.0     128.0
# 1            stationery.my      0.233559          17.0        17.0      19.0
# 2                 fooyin88      2.647002        8100.0      8100.0   21500.0
# 3                 vivi2002      2.709284        6500.0      6500.0    3400.0
# 4              xpro.gadget    852.957480          10.0        10.0     132.0
# ...                    ...           ...           ...         ...       ...
# 20307             amour.my      9.454468         219.0       219.0    1600.0
# 20308                mazu9      9.965184         215.0       215.0     304.0
# 20309  nurlainafashionzone      0.775416         152.0       152.0      98.0
# 20310           pbs_empire      0.093424          16.0        16.0      27.0
# 20311           ilham02_02      7.785300          89.0        89.0      61.0
#
#                                                     desc   Stock Ships_From  \
# 0      🎉 WELCOME To QQF WHOLESALE \r\n😍 ALL item read...    2906   Malaysia
# 1      Chinese Traditional Frog Buttons Knot Cheongsa...   31701      China
# 2      READY STOCK\nMEASUREMENT:\nLONG 26CM X HEIGHT ...    2044   Malaysia
# 3      PRODUCT DESCRIPTION\nMaterial:95%Cotton+5%Span...     386   Malaysia
# 4      Canon 70D\nHighlights\nEF-S 18-55mm f/3.5-5.6 ...      36   Malaysia
# ...                                                  ...     ...        ...
# 20307  1 cm = 0.3937 inch \r\n-----------------------...   19076      China
# 20308   M G FASHION\n-stylist fashionable\n-comfortab...    9406   Malaysia
# 20309   Harga utk 0.5m@setengah meter / HARGA BUKAN U...  446287   Malaysia
# 20310  Custom made Ready Stock in Malaysia\nUnicorn S...    3695   Malaysia
# 20311  @normal set bermaksud anda dapat set cermin ma...    6800   Malaysia
#
#        product_id        main_category           mid_category  \
# 0               1         Women's Bags          Shoulder Bags
# 1               2      Home Appliances        Sewing Machines
# 2               3         Women's Bags               Handbags
# 3               4        Women Clothes         Maternity Wear
# 4               5     Cameras & Drones           DSLR Cameras
# ...           ...                  ...                    ...
# 20307       20308          Baby & Toys          Girls Fashion
# 20308       20309          Baby & Toys          Girls Fashion
# 20309       20310       Muslim Fashion  Kain Pasang & Songket
# 20310       20311          Baby & Toys                 Others
# 20311       20312  Fashion Accessories                Eyewear
#
#                           sub_category  seller_id
# 0                        Shoulder Bags          1
# 1      Sewing Machines and Accessories          2
# 2                         Set Handbags          3
# 3                            Innerwear          4
# 4                                DSLRs          5
# ...                                ...        ...
# 20307                       Girl Shoes       1526
# 20308                     Girl Dresses       9226
# 20309               Kain Pasang Cotton       3749
# 20310                           Others       9227
# 20311                       Eyeglasses       4931
#
# [20312 rows x 17 columns]

# %%
products.to_csv(r'../Tables/products_table.csv')
orders.to_csv(r'../Tables/orders_table.csv')
delivery.to_csv(r'../Tables/deliveries_table.csv')
customer.to_csv(r'../Tables/customers_table.csv')
